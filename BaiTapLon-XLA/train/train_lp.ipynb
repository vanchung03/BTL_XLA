# %%
# !pip install ultralytics
# !pip install opencv-python-headless
# !pip install roboflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 898.5/898.5 kB 22.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.9/80.9 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip /content/dataset/Nhan_dien_bien_so_xe/dataset_bienso.zip -d /content/dataset2
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
#   inflating: /content/dataset2/dataset_bienso/train/labels/xemay626_jpg.rf.94536b0fcbd96c52d820082f4592027d.txt
#   inflating: /content/dataset2/dataset_bienso/train/labels/xemay628_jpg.rf.0a21a8c24c2f65f887110fdb66afbb60.txt
#   inflating: /content/dataset2/dataset_bienso/train/labels/xemay628_jpg.rf.10eacc91d60a194723a0a12d6af8b7cd.txt
#   inflating: /content/dataset2/dataset_bienso/train/labels/xemay628_jpg.rf.4e131b35dc7da8b1656f6d8730f77b0b.txt
#   inflating: /content/dataset2/dataset_bienso/train/labels/xemay62_jpg.rf.28bcf687d3e3c0f121d1fe1ccc030a0f.txt
#   inflating: /content/dataset2/dataset_bienso/train/labels/xemay62_jpg.rf.2cdfd45decf714d82f45dfa676c354b3.txt
#   inflating: /content/dataset2/dataset_bienso/train/labels/xemay62_jpg.rf.aeae8ec11b7ecb42ee88426f596fa27c.txt
#   inflating: /content/dataset2/dataset_bienso/train/labels/xemay630_jpg.rf.611b0a1f3001dc26ffef88d044ae3152.txt
# ...

# %%
import os
train_path = "/content/dataset2/dataset_bienso/train"
valid_path = "/content/dataset2/dataset_bienso/valid"

print("Train Images:", len(os.listdir(os.path.join(train_path, "images"))))
print("Train Labels:", len(os.listdir(os.path.join(train_path, "labels"))))
print("Validation Images:", len(os.listdir(os.path.join(valid_path, "images"))))
print("Validation Labels:", len(os.listdir(os.path.join(valid_path, "labels"))))
# Out:
# Train Images: 18915
# Train Labels: 18915
# Validation Images: 1822
# Validation Labels: 1822

# %%
from ultralytics import YOLO
import torch

device = 'cuda'

model = YOLO("yolov8n.pt")

model.train(data="/content/dataset2/dataset_bienso/data.yaml", epochs=20, imgsz=640, batch=32, device=device)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 104MB/s]
# Ultralytics 8.3.40 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...
